# %%
import numpy as np
import matplotlib.pyplot as plt
# Result collection\final_25epoch_collection\1 frame per second, Resnet 152, dropout 0.1, epoch 25

# %%
train_loss1_34 = np.load('Result collection/final_25epoch_collection/1 frame per second, Resnet 34, dropout 0.1, epoch 25/CRNN_epoch_training_losses.npy')
train_score1_34 = np.load('Result collection/final_25epoch_collection/1 frame per second, Resnet 34, dropout 0.1, epoch 25/CRNN_epoch_training_scores.npy')
test_loss1_34 = np.load('Result collection/final_25epoch_collection/1 frame per second, Resnet 34, dropout 0.1, epoch 25/CRNN_epoch_test_loss.npy')
test_score1_34 = np.load('Result collection/final_25epoch_collection/1 frame per second, Resnet 34, dropout 0.1, epoch 25/CRNN_epoch_test_score.npy')

# %%
train_loss2_34 = np.load('Result collection/final_25epoch_collection/2 frame per second, Resnet 34, dropout 0.1, epoch 25/CRNN_epoch_training_losses.npy')
train_score2_34 = np.load('Result collection/final_25epoch_collection/2 frame per second, Resnet 34, dropout 0.1, epoch 25/CRNN_epoch_training_scores.npy')
test_loss2_34 = np.load('Result collection/final_25epoch_collection/2 frame per second, Resnet 34, dropout 0.1, epoch 25/CRNN_epoch_test_loss.npy')
test_score2_34 = np.load('Result collection/final_25epoch_collection/2 frame per second, Resnet 34, dropout 0.1, epoch 25/CRNN_epoch_test_score.npy')

# %%
train_loss3_34 = np.load('Result collection/final_25epoch_collection/3 frame per second, Resnet 34, dropout 0.1, epoch 25/CRNN_epoch_training_losses.npy')
train_score3_34 = np.load('Result collection/final_25epoch_collection/3 frame per second, Resnet 34, dropout 0.1, epoch 25/CRNN_epoch_training_scores.npy')
test_loss3_34 = np.load('Result collection/final_25epoch_collection/3 frame per second, Resnet 34, dropout 0.1, epoch 25/CRNN_epoch_test_loss.npy')
test_score3_34 = np.load('Result collection/final_25epoch_collection/3 frame per second, Resnet 34, dropout 0.1, epoch 25/CRNN_epoch_test_score.npy')

# %%
train_loss1 = np.load('Result collection/final_25epoch_collection/1 frame per second, Resnet 152, dropout 0.1, epoch 25/CRNN_epoch_training_losses.npy')
train_score1 = np.load('Result collection/final_25epoch_collection/1 frame per second, Resnet 152, dropout 0.1, epoch 25/CRNN_epoch_training_scores.npy')
test_loss1 = np.load('Result collection/final_25epoch_collection/1 frame per second, Resnet 152, dropout 0.1, epoch 25/CRNN_epoch_test_loss.npy')
test_score1 = np.load('Result collection/final_25epoch_collection/1 frame per second, Resnet 152, dropout 0.1, epoch 25/CRNN_epoch_test_score.npy')

# %%
train_loss2 = np.load('Result collection/final_25epoch_collection/2 frame per second, Resnet 152, dropout 0.1, epoch 25/CRNN_epoch_training_losses.npy')
train_score2 = np.load('Result collection/final_25epoch_collection/2 frame per second, Resnet 152, dropout 0.1, epoch 25/CRNN_epoch_training_scores.npy')
test_loss2 = np.load('Result collection/final_25epoch_collection/2 frame per second, Resnet 152, dropout 0.1, epoch 25/CRNN_epoch_test_loss.npy')
test_score2 = np.load('Result collection/final_25epoch_collection/2 frame per second, Resnet 152, dropout 0.1, epoch 25/CRNN_epoch_test_score.npy')

# %%
train_loss3 = np.load('Result collection/final_25epoch_collection/3 frame per second, Resnet 152, dropout 0.1, epoch 25/CRNN_epoch_training_losses.npy')
train_score3 = np.load('Result collection/final_25epoch_collection/3 frame per second, Resnet 152, dropout 0.1, epoch 25/CRNN_epoch_training_scores.npy')
test_loss3 = np.load('Result collection/final_25epoch_collection/3 frame per second, Resnet 152, dropout 0.1, epoch 25/CRNN_epoch_test_loss.npy')
test_score3 = np.load('Result collection/final_25epoch_collection/3 frame per second, Resnet 152, dropout 0.1, epoch 25/CRNN_epoch_test_score.npy')

# %%
test_score1_34
# Out:
# array([0.43243243, 0.32432432, 0.43243243, 0.32432432, 0.48648649,
#        0.40540541, 0.48648649, 0.48648649, 0.35135135, 0.43243243,
#        0.54054054, 0.37837838, 0.35135135, 0.40540541, 0.43243243,
#        0.35135135, 0.37837838, 0.45945946, 0.48648649, 0.43243243,
#        0.45945946, 0.45945946, 0.43243243, 0.45945946, 0.40540541])

# %%
test_score2_34
# Out:
# array([0.2972973 , 0.40540541, 0.40540541, 0.40540541, 0.40540541,
#        0.45945946, 0.45945946, 0.51351351, 0.45945946, 0.43243243,
#        0.48648649, 0.62162162, 0.40540541, 0.43243243, 0.45945946,
#        0.59459459, 0.48648649, 0.59459459, 0.48648649, 0.45945946,
#        0.45945946, 0.48648649, 0.37837838, 0.32432432, 0.45945946])

# %%
test_score2+0.03
# Out:
# array([0.3272973 , 0.40837838, 0.46243243, 0.38135135, 0.43540541,
#        0.51648649, 0.35432432, 0.48945946, 0.46243243, 0.43540541,
#        0.48945946, 0.35432432, 0.3272973 , 0.48945946, 0.40837838,
#        0.38135135, 0.38135135, 0.54351351, 0.48945946, 0.51648649,
#        0.48945946, 0.43540541, 0.38135135, 0.35432432, 0.48945946])

# %%
test_score3_34
# Out:
# array([0.37837838, 0.37837838, 0.40540541, 0.43243243, 0.48648649,
#        0.48648649, 0.45945946, 0.45945946, 0.59459459, 0.51351351,
#        0.43243243, 0.40540541, 0.43243243, 0.45945946, 0.51351351,
#        0.37837838, 0.48648649, 0.48648649, 0.48648649, 0.48648649,
#        0.43243243, 0.2972973 , 0.59459459, 0.45945946, 0.48648649])

# %%
# test_score
print(np.average(test_score1_34),np.average(test_score2_34),np.average(test_score3_34))
# Out:
# 0.4237837837837838 0.45513513513513515 0.45729729729729734

# %%
print(np.average(test_score1),np.average(test_score2),np.average(test_score3))
# Out:
# 0.425945945945946 0.4021621621621623 0.42486486486486486

# %%
epochs = 25
fig = plt.figure(figsize=(20, 8))
plt.subplot(121)
# plt.plot(np.arange(1, epochs + 1), train_loss1[:, -1], 'r')  # train loss (on epoch end)

plt.plot(np.arange(1, epochs + 1), test_score2_34,'r')         #  test loss (on epoch end)
plt.plot(np.arange(1, epochs + 1), test_score2,'g')
# plt.plot(np.arange(1, epochs + 1), test_score1_34,'r')         #  test loss (on epoch end)
# plt.plot(np.arange(1, epochs + 1), test_score1,'g')
# plt.plot(np.arange(1, epochs + 1), test_score3_34,'r')         #  test loss (on epoch end)
# plt.plot(np.arange(1, epochs + 1), test_score3,'g')
# plt.plot(np.arange(1, epochs + 1), test_score2_34,'g')
# plt.plot(np.arange(1, epochs + 1), test_score3_34,'b')
plt.title("test accuracy")
# plt.title("model loss")
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['ResNet-34', 'ResNet-152','3-frame-per-second'])
# , loc="upper left"


# 2nd figure
# plt.subplot(122)
# plt.plot(np.arange(1, epochs + 1), train_score1[:, -1], 'r')  # train accuracy (on epoch end)
# plt.plot(np.arange(1, epochs + 1), test_score1, 'g')         #  test accuracy (on epoch end)
# plt.title("training scores")
# plt.xlabel('epochs')
# plt.ylabel('accuracy')
# plt.legend(['train', 'test'], loc="upper left")
# title = "./fig_Gingerbread_ResNetCRNN.png"
# plt.savefig(title, dpi=600)
# # plt.close(fig)
# plt.show()

# %%
epochs = 15
fig = plt.figure(figsize=(20, 8))
plt.subplot(121)
plt.plot(np.arange(1, epochs + 1), train_loss[:, -1], 'r')  # train loss (on epoch end)
plt.plot(np.arange(1, epochs + 1), test_loss, 'g')         #  test loss (on epoch end)
plt.title("model loss")
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc="upper left")

# %%
fig = plt.figure(figsize=(20, 8))
plt.subplot(122)
plt.plot(np.arange(1, epochs + 1), train_score[:, -1], 'r')  # train accuracy (on epoch end)
plt.plot(np.arange(1, epochs + 1), test_score, 'g')         #  test accuracy (on epoch end)
plt.title("training scores")
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['train', 'test'], loc="upper left")
title = "./fig_UCF101_ResNetCRNN.png"
plt.savefig(title, dpi=600)
# plt.close(fig)
plt.show()

# %%
1e-4
# Out:
# 0.0001
